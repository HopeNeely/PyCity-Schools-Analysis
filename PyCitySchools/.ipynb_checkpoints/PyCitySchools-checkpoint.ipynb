# %% [markdown]
# # City Schools Pandas Challenge

# %% [markdown]
# This analysis of the district-wide standardized test results aggregates data containing student's math and reading
# scores, as well as various information on the schools they attend. The purpose is to showcase obvious trends in school
# performance.

# %%
# Dependencies
import pandas as pd

# %%
# Store filepath for the school file
school_file = "Resources/schools_complete.csv"

# %%
#Store filepath for the student file
student_file = "Resources/students_complete.csv"

# %%
# Read the school file with the pandas library
school_df = pd.read_csv(school_file)
#school_df.head()

# %%
# Read the student file with the pandas library
student_df = pd.read_csv(student_file)
#student_df.head()

# %% [markdown]
# ## District Summary

# %% [markdown]
# This is a high level snapshot of the district's key metrics.

# %%
#Find district summary information, like total schools
total_schools = school_df["school_name"].count()
#total_schools

# %%
total_students = school_df["size"].sum()
#total_students

# %%
total_budget = school_df["budget"].sum()
#total_budget

# %%
average_math_score = student_df["math_score"].mean()
#average_math_score

# %%
average_reading_score = student_df["reading_score"].mean()
#average_reading_score

# %%
# Find percent of students passing math, start with total scores:
total_math_score = student_df["math_score"].count()
#total_math_score

# Find passing scores:
passing_math = student_df.loc[(student_df["math_score"] >= 60)]
total_passing_math = len(passing_math)
#passing_math_score
                   
percent_math_pass = total_passing_math / total_math_score   
#percent_math_pass

# %%
# Find percent of students passing reading, start with total scores:
total_reading_score = student_df["reading_score"].count()
#total_reading_score

passing_reading = student_df.loc[(student_df["reading_score"] >= 60)]
total_passing_reading = len(passing_reading)
#passing_reading_score
                   
percent_reading_pass = total_passing_reading / total_reading_score    
#percent_reading_pass

# %%
# Find percent of students passing both math and reading, start with total scores:
total_score = student_df["math_score"].count()
#total_score

passing_score = student_df.loc[(student_df["math_score"] >= 60) & (student_df["reading_score"] >= 60)]
total_passing_score = len(passing_score)
                   
percent_pass = total_passing_score / total_score   
#percent_pass

# %%
district_summary_df = pd.DataFrame(
    {"Total Schools": [total_schools], 
     "Total Students": [total_students],
     "Total Budget": [total_budget],
     "Average Math Score": [average_math_score],
     "Average Reading Score": [average_reading_score],
     "% Passing Math": [percent_math_pass],
     "% Passing Reading": [percent_reading_pass],
     "% Overall Passing": [percent_pass]
                       })
#district_summary_df

# %%
# Use Map to format all the columns
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,}".format)
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.0f}".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.0f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.2f}".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.2f}".format)
district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.2f}".format)
district_summary_df
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428                 79
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                    82           0.92              1.00              0.92

# %% [markdown]
# ## School Summary

# %% [markdown]
# Serves as an overview of key metrics on each school.

# %%
# Merge school dateframe with student dataframe using an outer join at school name
merge_df = pd.merge(school_df, student_df, on="school_name", how="outer")
#merge_df.head()

# %%
# add in columns needed for analysis
merge_df['Per Student Budget'] = merge_df['budget'] / merge_df['size']
merge_df["% Passing Math"] = merge_df["math_score"] >= 60
merge_df["% Passing Reading"] = merge_df["reading_score"] >= 60
merge_df["% Overall Passing"] = (merge_df["math_score"]>=60) & (merge_df["reading_score"]>=60)

# delete columns not needed for further analysis
del merge_df["School ID"]
del merge_df["Student ID"]
#merge_df.head()

# %%
# Rename columns
merge_df = merge_df.rename(columns={
    "school_name":"School Name", 
    "type":"School Type", 
    "size":"Total Students",
    "budget": "Total School Budget",
    "math_score": "Average Math Score",
    "reading_score": "Average Reading Score"}) 
#merge_df.head()

# %%
school_summary_df = merge_df.groupby(['School Name','School Type']).mean()
#school_summary_df.head()

# %%
#school_summary_df["Total Students"] = school_summary_df["Total Students"].map("{:,}".format)
school_summary_df["Total School Budget"] = school_summary_df["Total School Budget"].map("${:,}".format)
school_summary_df["Per Student Budget"] = school_summary_df["Per Student Budget"].map("${:,}".format)
school_summary_df["Average Math Score"] = school_summary_df["Average Math Score"].map("{:.0f}".format)
school_summary_df["Average Reading Score"] = school_summary_df["Average Reading Score"].map("{:.0f}".format)
school_summary_df["% Passing Math"] = school_summary_df["% Passing Math"].map("{:.2f}".format)
school_summary_df["% Passing Reading"] = school_summary_df["% Passing Reading"].map("{:.2f}".format)
school_summary_df["% Overall Passing"] = school_summary_df["% Overall Passing"].map("{:.2f}".format)
school_summary_df
# Out:
#                                    Total Students Total School Budget  \
# School Name           School Type
# Bailey High School    District             4976.0        $3,124,928.0
# Cabrera High School   Charter              1858.0        $1,081,356.0
# Figueroa High School  District             2949.0        $1,884,411.0
# Ford High School      District             2739.0        $1,763,916.0
# Griffin High School   Charter              1468.0          $917,500.0
# Hernandez High School District             4635.0        $3,022,020.0
# Holden High School    Charter               427.0          $248,087.0
# Huang High School     District             2917.0        $1,910,635.0
# Johnson High School   District             4761.0        $3,094,650.0
# Pena High School      Charter               962.0          $585,858.0
# Rodriguez High School District             3999.0        $2,547,363.0
# Shelton High School   Charter              1761.0        $1,056,600.0
# Thomas High School    Charter              1635.0        $1,043,130.0
# Wilson High School    Charter              2283.0        $1,319,574.0
# Wright High School    Charter              1800.0        $1,049,400.0
#
#                                   Average Reading Score Average Math Score  \
# School Name           School Type
# Bailey High School    District                       81                 77
# Cabrera High School   Charter                        84                 83
# Figueroa High School  District                       81                 77
# Ford High School      District                       81                 77
# Griffin High School   Charter                        84                 83
# Hernandez High School District                       81                 77
# Holden High School    Charter                        84                 84
# Huang High School     District                       81                 77
# Johnson High School   District                       81                 77
# Pena High School      Charter                        84                 84
# Rodriguez High School District                       81                 77
# Shelton High School   Charter                        84                 83
# Thomas High School    Charter                        84                 83
# Wilson High School    Charter                        84                 83
# Wright High School    Charter                        84                 84
#
#                                   Per Student Budget % Passing Math  \
# School Name           School Type
# Bailey High School    District                $628.0           0.90
# Cabrera High School   Charter                 $582.0           1.00
# Figueroa High School  District                $639.0           0.88
# Ford High School      District                $644.0           0.89
# Griffin High School   Charter                 $625.0           1.00
# Hernandez High School District                $652.0           0.89
# Holden High School    Charter                 $581.0           1.00
# Huang High School     District                $655.0           0.89
# Johnson High School   District                $650.0           0.89
# Pena High School      Charter                 $609.0           1.00
# Rodriguez High School District                $637.0           0.89
# Shelton High School   Charter                 $600.0           1.00
# Thomas High School    Charter                 $638.0           1.00
# Wilson High School    Charter                 $578.0           1.00
# Wright High School    Charter                 $583.0           1.00
#
#                                   % Passing Reading % Overall Passing
# School Name           School Type
# Bailey High School    District                 1.00              0.90
# Cabrera High School   Charter                  1.00              1.00
# Figueroa High School  District                 1.00              0.88
# Ford High School      District                 1.00              0.89
# Griffin High School   Charter                  1.00              1.00
# Hernandez High School District                 1.00              0.89
# Holden High School    Charter                  1.00              1.00
# Huang High School     District                 1.00              0.89
# Johnson High School   District                 1.00              0.89
# Pena High School      Charter                  1.00              1.00
# Rodriguez High School District                 1.00              0.89
# Shelton High School   Charter                  1.00              1.00
# Thomas High School    Charter                  1.00              1.00
# Wilson High School    Charter                  1.00              1.00
# Wright High School    Charter                  1.00              1.00

# %% [markdown]
# ## Bottom Performing Schools

# %% [markdown]
# Table shows bottom 5 performing schools based on % Overall Passing.

# %%
bottom_performing_df = school_summary_df.sort_values("% Overall Passing")
bottom_performing_df.head(5)
# Out:
#                                    Total Students Total School Budget  \
# School Name           School Type
# Figueroa High School  District             2949.0        $1,884,411.0
# Ford High School      District             2739.0        $1,763,916.0
# Hernandez High School District             4635.0        $3,022,020.0
# Huang High School     District             2917.0        $1,910,635.0
# Johnson High School   District             4761.0        $3,094,650.0
#
#                                   Average Reading Score Average Math Score  \
# School Name           School Type
# Figueroa High School  District                       81                 77
# Ford High School      District                       81                 77
# Hernandez High School District                       81                 77
# Huang High School     District                       81                 77
# Johnson High School   District                       81                 77
#
#                                   Per Student Budget % Passing Math  \
# School Name           School Type
# Figueroa High School  District                $639.0           0.88
# Ford High School      District                $644.0           0.89
# Hernandez High School District                $652.0           0.89
# Huang High School     District                $655.0           0.89
# Johnson High School   District                $650.0           0.89
#
#                                   % Passing Reading % Overall Passing
# School Name           School Type
# Figueroa High School  District                 1.00              0.88
# Ford High School      District                 1.00              0.89
# Hernandez High School District                 1.00              0.89
# Huang High School     District                 1.00              0.89
# Johnson High School   District                 1.00              0.89

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# Table lists the average math score for students of each grade level (9th, 10th, 11th, 12th) at each school

# %%
groupby_grade_df = merge_df.groupby(['School Name', 'grade']).mean()
#groupby_grade_df.head()

# %%
# Add in formating
groupby_grade_df["Total School Budget"] = groupby_grade_df["Total School Budget"].map("${:,}".format)
groupby_grade_df["Per Student Budget"] = groupby_grade_df["Per Student Budget"].map("${:,}".format)
groupby_grade_df["Average Math Score"] = groupby_grade_df["Average Math Score"].map("{:.0f}".format)
groupby_grade_df["Average Reading Score"] = groupby_grade_df["Average Reading Score"].map("{:.0f}".format)
groupby_grade_df["% Passing Math"] = groupby_grade_df["% Passing Math"].map("{:.2f}".format)
groupby_grade_df["% Passing Reading"] = groupby_grade_df["% Passing Reading"].map("{:.2f}".format)
groupby_grade_df["% Overall Passing"] = groupby_grade_df["% Overall Passing"].map("{:.2f}".format)
groupby_grade_df
# Out:
#                              Total Students Total School Budget  \
# School Name           grade
# Bailey High School    10th           4976.0        $3,124,928.0
#                       11th           4976.0        $3,124,928.0
#                       12th           4976.0        $3,124,928.0
#                       9th            4976.0        $3,124,928.0
# Cabrera High School   10th           1858.0        $1,081,356.0
#                       11th           1858.0        $1,081,356.0
#                       12th           1858.0        $1,081,356.0
#                       9th            1858.0        $1,081,356.0
# Figueroa High School  10th           2949.0        $1,884,411.0
#                       11th           2949.0        $1,884,411.0
#                       12th           2949.0        $1,884,411.0
#                       9th            2949.0        $1,884,411.0
# Ford High School      10th           2739.0        $1,763,916.0
#                       11th           2739.0        $1,763,916.0
#                       12th           2739.0        $1,763,916.0
#                       9th            2739.0        $1,763,916.0
# Griffin High School   10th           1468.0          $917,500.0
#                       11th           1468.0          $917,500.0
#                       12th           1468.0          $917,500.0
#                       9th            1468.0          $917,500.0
# Hernandez High School 10th           4635.0        $3,022,020.0
#                       11th           4635.0        $3,022,020.0
#                       12th           4635.0        $3,022,020.0
#                       9th            4635.0        $3,022,020.0
# Holden High School    10th            427.0          $248,087.0
